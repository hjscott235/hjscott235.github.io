# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from sklearn import linear_model
import statsmodels.api as sm
plt.rc("font", size=14)
from statsmodels.sandbox.regression.predstd import wls_prediction_std
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures

# %%
raw = pd.read_excel('car-counts.xlsx')
raw['imaging_ts']=pd.to_datetime(raw['imaging_ts'])
raw['day']=raw['imaging_ts'].dt.dayofweek #Create a "day of the week" column from timestamp. 0=Monday, 6=Sunday
#initially planned to make an "hour/time of day" column and found that images were all taken around the same time.
print(raw.shape)
print(raw.columns)
print(raw.dtypes)
# Out:
# (51, 7)
# Index(['imaging_ts', 'tile_id', 'cloud_score', 'objects detected', 'day',
#        'month', 'year'],
#       dtype='object')
# imaging_ts          datetime64[ns]
# tile_id                     object
# cloud_score                float64
# objects detected             int64
# day                          int64
# month                        int64
# year                         int64
# dtype: object

# %%
raw['tile_id'].unique()
## group by day - data dict said that daily counts should be summed
grouped = raw.groupby(['imaging_ts','day'], as_index=False)['objects detected'].sum()
print(grouped.dtypes)
# want to add cloud_score back into dataset
# should I take average of cloud score per day?
grouped = grouped.merge(raw[['cloud_score','imaging_ts']], 
                        left_on = 'imaging_ts', right_on = 'imaging_ts')
grouped = grouped.groupby(['imaging_ts','day','objects detected'], as_index=False)['cloud_score'].mean()
grouped['month']=grouped['imaging_ts'].dt.month
grouped['year']=grouped['imaging_ts'].dt.year
# Out:
# imaging_ts          datetime64[ns]
# day                          int64
# objects detected             int64
# dtype: object
#                 imaging_ts  day  objects detected  cloud_score  month  year
# 0  2009-07-11 18:59:31.886    5               111     0.334568      7  2009
# 1  2009-07-14 19:03:22.428    1               249     0.499609      7  2009
# 2  2010-05-04 18:58:35.566    1               252     0.201999      5  2010
# 3  2010-08-14 19:01:14.612    5                90     0.069129      8  2010
# 4  2010-09-25 19:13:56.172    5               135     0.001599      9  2010
# 5  2010-10-02 19:10:03.182    5               102     0.005467     10  2010
# 6  2011-05-13 19:07:46.221    4               280     0.520145      5  2011
# 7  2011-11-14 19:11:16.588    0               338     0.044485     11  2011
# 8  2011-11-25 19:07:37.003    4                12     0.199589     11  2011
# 9  2012-03-06 18:59:22.685    1               339     0.169484      3  2012
# 10 2012-07-12 19:40:15.556    3               313     0.436219      7  2012
# 11 2012-12-01 19:04:16.973    5                61     0.021526     12  2012
# 12 2013-04-18 19:19:08.743    3               296     0.203881      4  2013
# 13 2013-06-04 18:53:18.775    1               310     0.577538      6  2013
# 14 2014-07-13 19:03:50.175    6               114     0.385802      7  2014
# 15 2014-07-26 18:45:22.397    5                77     0.382868      7  2014
# 16 2014-12-25 18:49:48.511    3                18     0.465692     12  2014
# 17 2015-04-02 18:53:22.221    3               305     0.460205      4  2015
# 18 2015-04-05 19:47:52.752    6                16     0.721085      4  2015
# 19 2015-06-20 20:10:55.484    5               125     0.432728      6  2015
# 20 2015-10-11 19:11:15.591    6                89     0.059240     10  2015
# 21 2016-06-07 18:37:09.285    1               138     0.939567      6  2016
# 22 2016-06-11 19:13:48.685    5               152     0.585558      6  2016
# 23 2016-06-15 19:15:49.270    2               199     0.680712      6  2016
# 24 2016-06-20 18:41:19.949    0               176     0.749894      6  2016
# 25 2016-08-25 18:40:54.085    3               278     0.000383      8  2016
# 26 2016-09-04 18:37:07.381    6                23     0.000658      9  2016

# %% [markdown]
# ### Exploring and/or Cleaning Data

# %%
# Summary statistics for # of Objects Detected and Cloud Score
grouped[['objects detected','cloud_score']].describe()
# Out:
#        objects detected  cloud_score
# count         27.000000    27.000000
# mean         170.296296     0.338875
# std          109.414812     0.270308
# min           12.000000     0.000383
# 25%           89.500000     0.064184
# 50%          138.000000     0.382868
# 75%          279.000000     0.509877
# max          339.000000     0.939567

# %%
# Objects detected by day
grouped.groupby(['year'])['objects detected'].describe()
# Out:
#       count        mean         std    min     25%    50%     75%    max
# year
# 2009    2.0  180.000000   97.580736  111.0  145.50  180.0  214.50  249.0
# 2010    4.0  144.750000   73.988175   90.0   99.00  118.5  164.25  252.0
# 2011    3.0  210.000000  173.908022   12.0  146.00  280.0  309.00  338.0
# 2012    3.0  237.666667  153.549124   61.0  187.00  313.0  326.00  339.0
# 2013    2.0  303.000000    9.899495  296.0  299.50  303.0  306.50  310.0
# 2014    3.0   69.666667   48.418316   18.0   47.50   77.0   95.50  114.0
# 2015    4.0  133.750000  122.842379   16.0   70.75  107.0  170.00  305.0
# 2016    6.0  161.000000   83.680344   23.0  141.50  164.0  193.25  278.0

# %%
#filter out zeros (later on we want to do a log output of Y)
filtered = full[full['objects detected']>0]
filtered['objects detected'].describe()
#try Logarithmic val of Objects detected
filtered['logobs']=np.log(filtered['objects detected'])
#try Log val of cloud score
filtered['logcloud']=np.log10(filtered['cloud_score'])
#try square/square-root
filtered['sqrtcloud']=np.sqrt(filtered['cloud_score'])
filtered['sqcloud']=np.power(filtered['cloud_score'],2)

# %%
#show general distribution of objects detected
filtered['objects detected'].hist(bins=10,grid=False)
plt.title("Objects Detected, Distribution")
plt.show()
# note to self - less of a normal distribution than expected
graph2 = plt.scatter(grouped['objects detected'],grouped['cloud_score'])
plt.title("Objects Detected by Cloud Score")
plt.show()
plt.scatter(filtered['logobs'],filtered['cloud_score'])
plt.title("Log Objects Detected by Cloud Score")
plt.show()
plt.scatter(filtered['objects detected'],filtered['logcloud'])
plt.title("Objects Detected by log-based2 Cloud Score")
plt.show()
plt.scatter(filtered['objects detected'],filtered['sqrtcloud'])
plt.title("Objects Detected by Square Root Cloud Score")
plt.show()
plt.scatter(filtered['objects detected'],filtered['sqcloud'])
plt.title("Objects Detected by Square Cloud Score")
plt.show()

# %%
Y = filtered['objects detected']
X = filtered[['cloud_score','day']]

regress = linear_model.LinearRegression()
regress.fit(X, Y)

print('Intercept: \n', regress.intercept_)
print('Coefficients: \n', regress.coef_)

X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# Intercept:
#  334.2278376446931
# Coefficients:
#  [-71.79244806 -40.09869456]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       objects detected   R-squared:                       0.482
# Model:                            OLS   Adj. R-squared:                  0.438
# Method:                 Least Squares   F-statistic:                     11.15
# Date:                Sun, 04 Oct 2020   Prob (F-statistic):           0.000377
# Time:                        20:08:48   Log-Likelihood:                -155.70
# No. Observations:                  27   AIC:                             317.4
# Df Residuals:                      24   BIC:                             321.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         334.2278     44.391      7.529      0.000     242.610     425.846
# cloud_score   -71.7924     62.617     -1.147      0.263    -201.028      57.443
# day           -40.0987      8.515     -4.709      0.000     -57.672     -22.525
# ==============================================================================
# Omnibus:                        0.068   Durbin-Watson:                   2.456
# Prob(Omnibus):                  0.967   Jarque-Bera (JB):                0.229
# Skew:                          -0.099   Prob(JB):                        0.892
# Kurtosis:                       2.594   Cond. No.                         18.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
Y = filtered['logobs']
X = filtered[['cloud_score','day']]

regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# Intercept:
#  5.9819780438365955
# Coefficients:
#  [-0.44808297 -0.2937886 ]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 logobs   R-squared:                       0.322
# Model:                            OLS   Adj. R-squared:                  0.265
# Method:                 Least Squares   F-statistic:                     5.687
# Date:                Sun, 04 Oct 2020   Prob (F-statistic):            0.00952
# Time:                        20:08:52   Log-Likelihood:                -32.142
# No. Observations:                  27   AIC:                             70.28
# Df Residuals:                      24   BIC:                             74.17
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           5.9820      0.457     13.092      0.000       5.039       6.925
# cloud_score    -0.4481      0.645     -0.695      0.494      -1.778       0.882
# day            -0.2938      0.088     -3.352      0.003      -0.475      -0.113
# ==============================================================================
# Omnibus:                       11.478   Durbin-Watson:                   2.341
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               10.071
# Skew:                          -1.333   Prob(JB):                      0.00650
# Kurtosis:                       4.359   Cond. No.                         18.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
Y = filtered['objects detected']
X = filtered[['logcloud','day']]

regress = linear_model.LinearRegression()
regress.fit(X, Y)

print('Intercept: \n', regress.intercept_)
print('Coefficients: \n', regress.coef_)

X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# Intercept:
#  295.63380091804794
# Coefficients:
#  [ -8.97755737 -38.30635101]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       objects detected   R-squared:                       0.459
# Model:                            OLS   Adj. R-squared:                  0.414
# Method:                 Least Squares   F-statistic:                     10.18
# Date:                Sun, 04 Oct 2020   Prob (F-statistic):           0.000630
# Time:                        20:08:52   Log-Likelihood:                -156.28
# No. Observations:                  27   AIC:                             318.6
# Df Residuals:                      24   BIC:                             322.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        295.6338     33.775      8.753      0.000     225.925     365.342
# logcloud      -8.9776     17.834     -0.503      0.619     -45.786      27.830
# day          -38.3064      8.632     -4.438      0.000     -56.121     -20.491
# ==============================================================================
# Omnibus:                        0.323   Durbin-Watson:                   2.360
# Prob(Omnibus):                  0.851   Jarque-Bera (JB):                0.479
# Skew:                          -0.194   Prob(JB):                        0.787
# Kurtosis:                       2.475   Cond. No.                         9.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
Y = filtered['objects detected']
X = filtered[['sqcloud','day']]

regress = linear_model.LinearRegression()
regress.fit(X, Y)

print('Intercept: \n', regress.intercept_)
print('Coefficients: \n', regress.coef_)

X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# Intercept:
#  340.87693947806287
# Coefficients:
#  [-133.59874002  -41.88981332]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       objects detected   R-squared:                       0.517
# Model:                            OLS   Adj. R-squared:                  0.477
# Method:                 Least Squares   F-statistic:                     12.83
# Date:                Sun, 04 Oct 2020   Prob (F-statistic):           0.000162
# Time:                        20:08:53   Log-Likelihood:                -154.75
# No. Observations:                  27   AIC:                             315.5
# Df Residuals:                      24   BIC:                             319.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        340.8769     38.970      8.747      0.000     260.447     421.307
# sqcloud     -133.5987     75.159     -1.778      0.088    -288.719      21.522
# day          -41.8898      8.270     -5.065      0.000     -58.959     -24.820
# ==============================================================================
# Omnibus:                        0.458   Durbin-Watson:                   2.487
# Prob(Omnibus):                  0.795   Jarque-Bera (JB):                0.185
# Skew:                          -0.201   Prob(JB):                        0.912
# Kurtosis:                       2.939   Cond. No.                         21.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
